# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import to_categorical

data=load_digits()

X_train,X_test,y_train,y_test=train_test_split(data.data, data.target, test_size=0.3,random_state=0)

ann=Sequential()
ann.add(Dense(units=128, input_dim=X_train.shape[1]))
ann.add(Activation('relu'))
ann.add(Dense(units=10))
ann.add(Activation('softmax'))

ann.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)
ann.fit(X_train,y_train_cat,epochs=50,batch_size=32,validation_data=(X_test,y_test_cat))

loss,accuracy=ann.evaluate(X_test, y_test_cat, batch_size=32)
print("Test Loss:", loss)
print("Test Accuracy: " + str(accuracy))
# Out:
# Epoch 1/50
# 40/40 [==============================] - 4s 46ms/step - loss: 2.3702 - accuracy: 0.4678 - val_loss: 0.7443 - val_accuracy: 0.7556
# Epoch 2/50
# 40/40 [==============================] - 1s 18ms/step - loss: 0.3817 - accuracy: 0.8886 - val_loss: 0.3975 - val_accuracy: 0.8833
# Epoch 3/50
# 40/40 [==============================] - 1s 25ms/step - loss: 0.2262 - accuracy: 0.9324 - val_loss: 0.2814 - val_accuracy: 0.9185
# Epoch 4/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.1594 - accuracy: 0.9602 - val_loss: 0.2569 - val_accuracy: 0.9259
# Epoch 5/50
# 40/40 [==============================] - 1s 19ms/step - loss: 0.1150 - accuracy: 0.9730 - val_loss: 0.1909 - val_accuracy: 0.9444
# Epoch 6/50
# 40/40 [==============================] - 1s 18ms/step - loss: 0.0898 - accuracy: 0.9793 - val_loss: 0.1752 - val_accuracy: 0.9500
# Epoch 7/50
# 40/40 [==============================] - 1s 24ms/step - loss: 0.0723 - accuracy: 0.9857 - val_loss: 0.1647 - val_accuracy: 0.9444
# Epoch 8/50
# 40/40 [==============================] - 1s 15ms/step - loss: 0.0645 - accuracy: 0.9857 - val_loss: 0.1399 - val_accuracy: 0.9537
# Epoch 9/50
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0492 - accuracy: 0.9897 - val_loss: 0.1602 - val_accuracy: 0.9537
# Epoch 10/50
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0435 - accuracy: 0.9928 - val_loss: 0.1479 - val_accuracy: 0.9519
# Epoch 11/50
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0327 - accuracy: 0.9968 - val_loss: 0.1272 - val_accuracy: 0.9593
# Epoch 12/50
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0284 - accuracy: 0.9968 - val_loss: 0.1292 - val_accuracy: 0.9593
# Epoch 13/50
# 40/40 [==============================] - 1s 23ms/step - loss: 0.0253 - accuracy: 0.9960 - val_loss: 0.1229 - val_accuracy: 0.9611
# Epoch 14/50
# 40/40 [==============================] - 1s 20ms/step - loss: 0.0217 - accuracy: 0.9976 - val_loss: 0.1169 - val_accuracy: 0.9630
# Epoch 15/50
# 40/40 [==============================] - 0s 12ms/step - loss: 0.0184 - accuracy: 0.9984 - val_loss: 0.1184 - val_accuracy: 0.9574
# Epoch 16/50
# 40/40 [==============================] - 1s 34ms/step - loss: 0.0168 - accuracy: 0.9984 - val_loss: 0.1104 - val_accuracy: 0.9630
# Epoch 17/50
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0142 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9648
# Epoch 18/50
# 40/40 [==============================] - 1s 16ms/step - loss: 0.0137 - accuracy: 0.9992 - val_loss: 0.1111 - val_accuracy: 0.9648
# Epoch 19/50
# 40/40 [==============================] - 1s 19ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9611
# Epoch 20/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.9667
# Epoch 21/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1002 - val_accuracy: 0.9685
# Epoch 22/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.1079 - val_accuracy: 0.9611
# Epoch 23/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9630
# Epoch 24/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 0.0993 - val_accuracy: 0.9704
# Epoch 25/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0969 - val_accuracy: 0.9722
# Epoch 26/50
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9667
# Epoch 27/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0975 - val_accuracy: 0.9685
# Epoch 28/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9685
# Epoch 29/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9685
# Epoch 30/50
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0966 - val_accuracy: 0.9667
# Epoch 31/50
# 40/40 [==============================] - 1s 14ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0979 - val_accuracy: 0.9704
# Epoch 32/50
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.0957 - val_accuracy: 0.9704
# Epoch 33/50
# 40/40 [==============================] - 0s 10ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0948 - val_accuracy: 0.9704
# Epoch 34/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9704
# Epoch 35/50
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.0964 - val_accuracy: 0.9704
# Epoch 36/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9704
# Epoch 37/50
# 40/40 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9722
# Epoch 38/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0949 - val_accuracy: 0.9704
# Epoch 39/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9722
# Epoch 40/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0938 - val_accuracy: 0.9704
# Epoch 41/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0962 - val_accuracy: 0.9704
# Epoch 42/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9741
# Epoch 43/50
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9704
# Epoch 44/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0926 - val_accuracy: 0.9741
# Epoch 45/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0922 - val_accuracy: 0.9722
# Epoch 46/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0998 - val_accuracy: 0.9704
# Epoch 47/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9722
# Epoch 48/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0933 - val_accuracy: 0.9704
# Epoch 49/50
# 40/40 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0959 - val_accuracy: 0.9722
# Epoch 50/50
# 40/40 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0913 - val_accuracy: 0.9741
# 17/17 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9741
# Test Loss: 0.09134203940629959
# Test Accuracy: 0.9740740656852722

# %%
#ORRRRRRRRRRRRRRRRRRRRRRRRRRRRRRRR

from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
import numpy as np
import tensorflow as tf

# Load the digits dataset
digits = load_digits()

# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.3, random_state=42)

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, activation='relu', input_shape=(64,)),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=10)

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/10
# 40/40 [==============================] - 2s 2ms/step - loss: 1.9558 - accuracy: 0.5322
# Epoch 2/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.3799 - accuracy: 0.8831
# Epoch 3/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2137 - accuracy: 0.9427
# Epoch 4/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1495 - accuracy: 0.9554
# Epoch 5/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1198 - accuracy: 0.9674
# Epoch 6/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0898 - accuracy: 0.9761
# Epoch 7/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0730 - accuracy: 0.9817
# Epoch 8/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0603 - accuracy: 0.9825
# Epoch 9/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9920
# Epoch 10/10
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0459 - accuracy: 0.9881
# 17/17 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9667
# Test accuracy: 0.9666666388511658
